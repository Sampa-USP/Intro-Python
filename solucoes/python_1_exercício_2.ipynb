# %%
import numpy as np

lista = list(np.random.uniform(0,100,size=(200)))
encontrar_menor(lista)

menor = +201

def encontrar_menor(lista):
    menor = +101
    for numero in lista:
        if numero < menor :
            menor = numero
            
    return menor

# %%
def fibonacci(n):

    lista = [1,1]

    for i in range(n - 2):
        fibo = lista[-2] + lista[-1]
        lista.append(fibo)
    
    return lista[-1]

# %%
x = "Paulo"

# %%
len(x)
# Out:
# 5

# %%
len(lista)
# Out:
# 200

# %%
x.upper()
# Out:
# 'PAULO'

# %%
lista.sort()

# %%
lista
# Out:
# [0.65387466516591,
#  0.7197357398514681,
#  3.1472761757290524,
#  3.412066511283518,
#  4.2053550907048205,
#  4.803566205988885,
#  5.0090189898805875,
#  6.914634395899888,
#  8.07209710697755,
#  8.141619959842572,
#  8.378742826753715,
#  8.56666836742449,
#  9.049749128288276,
#  9.070352455815812,
#  10.003961224209934,
#  10.5809734623313,
#  10.746082666317058,
#  11.751426424411449,
#  11.9667146241474,
#  12.269461343809596,
#  12.382796503424043,
#  14.492797297334391,
#  14.854768334925794,
#  14.98348284568064,
#  15.637042434940184,
#  15.699584269336132,
#  15.769338942021271,
#  16.342255037218457,
#  16.48125565002183,
#  16.559923268139933,
#  16.576325627719502,
#  18.26620498395698,
#  18.952526274004278,
#  19.10713398874443,
#  21.689666327321888,
#  22.145126202046217,
#  22.68061035407132,
#  22.690155438708402,
#  23.423522940745066,
#  23.507680186140835,
#  23.71626398500093,
#  24.17039643403367,
#  24.380940639544047,
#  24.787922707768605,
# ...
